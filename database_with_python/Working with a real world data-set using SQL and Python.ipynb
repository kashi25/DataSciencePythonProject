# %% [markdown]
# # Working with a real world data-set using SQL and Python

# %%
import csv, sqlite3
conn = sqlite3.connect("realworld_data.db")
cur = conn.cursor()

# %%
# %load_ext sql

# %%
# %sql sqlite:///realworld_data.db
# Out:
# 'Connected: @realworld_data.db'

# %%
import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv")
df.to_sql("Census_data", conn, if_exists='replace', index=False, method="multi")
# Out:
# 78

# %%
df.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 0                                          18.2
# ...

# %% [markdown]
# ### Query the database system catalog to retrieve table metadata
#
# ##### You can verify that the table creation was successful by retrieving the list of all tables in your schema and checking whether the SCHOOLS table was created

# %%
# %sql select COMMUNITY_AREA_NUMBER,COMMUNITY_AREA_NAME from Census_data limit 5;
# Out:
#  * sqlite:///realworld_data.db
# Done.
# [(1.0, 'Rogers Park'),
#  (2.0, 'West Ridge'),
#  (3.0, 'Uptown'),
#  (4.0, 'Lincoln Square'),
#  (5.0, 'North Center')]

# %%
# %sql select * from Census_data limit 5;
# Out:
#  * sqlite:///realworld_data.db
# Done.
# [(1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0)]

# %%
# %sql SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///realworld_data.db
# Done.
# [('Census_data',)]

# %%
colu=df.columns
colu
# Out:
# Index(['COMMUNITY_AREA_NUMBER', 'COMMUNITY_AREA_NAME',
#        'PERCENT_OF_HOUSING_CROWDED', 'PERCENT_HOUSEHOLDS_BELOW_POVERTY',
#        'PERCENT_AGED_16__UNEMPLOYED',
#        'PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA',
#        'PERCENT_AGED_UNDER_18_OR_OVER_64', 'PER_CAPITA_INCOME',
#        'HARDSHIP_INDEX'],
#       dtype='object')

# %%
# type in your query to retrieve the number of columns in the Census_data table
# %sql select count(name) from PRAGMA_TABLE_INFO('Census_data');
# Out:
#  * sqlite:///realworld_data.db
# Done.
# [(9,)]

# %%
# type in your query to retrieve all column names in the Census_data table along with their datatypes and length
# %sql SELECT name,type,length(type) FROM PRAGMA_TABLE_INFO('Census_data');
# Out:
#  * sqlite:///realworld_data.db
# Done.
# [('COMMUNITY_AREA_NUMBER', 'REAL', 4),
#  ('COMMUNITY_AREA_NAME', 'TEXT', 4),
#  ('PERCENT_OF_HOUSING_CROWDED', 'REAL', 4),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'REAL', 4),
#  ('PERCENT_AGED_16__UNEMPLOYED', 'REAL', 4),
#  ('PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'REAL', 4),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'REAL', 4),
#  ('PER_CAPITA_INCOME', 'INTEGER', 7),
#  ('HARDSHIP_INDEX', 'REAL', 4)]

# %% [markdown]
# <h1 align=center><font size = 5>Assignment: Notebook for Graded Assessment</font></h1>

# %% [markdown]
# Problem 1
# Find the total number of crimes recorded in the CRIME table.

# %%
import csv,sqlite3
conn = sqlite3.connect("FinalDB.db")
cur = conn.cursor()

# %%
# %reload_ext sql

# %%
# %sql sqlite:///FinalDB.db
# Out:
# 'Connected: @FinalDB.db'

# %%
import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("Crime_data",conn, if_exists="replace", index=False, method="multi")
df.head()
# Out:
#          ID CASE_NUMBER        DATE                     BLOCK IUCR  \
# 0   3512276    HK587712  2004-08-28        047XX S KEDZIE AVE  890
# 1   3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE  820
# 2   8002131    HT233595  2011-04-04        043XX S WABASH AVE  820
# 3   7903289    HT133522  2010-12-30      083XX S KINGSTON AVE  840
# 4  10402076    HZ138551  2016-02-02           033XX W 66TH ST  820
#
#   PRIMARY_TYPE                    DESCRIPTION          LOCATION_DESCRIPTION  \
# 0        THEFT                  FROM BUILDING            SMALL RETAIL STORE
# 1        THEFT                 $500 AND UNDER                         OTHER
# 2        THEFT                 $500 AND UNDER  NURSING HOME/RETIREMENT HOME
# 3        THEFT  FINANCIAL ID THEFT: OVER $300                     RESIDENCE
# 4        THEFT                 $500 AND UNDER                         ALLEY
#
#    ARREST  DOMESTIC  ...  DISTRICT  WARD  COMMUNITY_AREA_NUMBER  FBICODE  \
# ...

# %%
coln = df.columns
coln
# Out:
# Index(['ID', 'CASE_NUMBER', 'DATE', 'BLOCK', 'IUCR', 'PRIMARY_TYPE',
#        'DESCRIPTION', 'LOCATION_DESCRIPTION', 'ARREST', 'DOMESTIC', 'BEAT',
#        'DISTRICT', 'WARD', 'COMMUNITY_AREA_NUMBER', 'FBICODE', 'X_COORDINATE',
#        'Y_COORDINATE', 'YEAR', 'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
# SELECT column_name, COUNT(column_name) AS repetition_count
# FROM table_name
# GROUP BY column_name
# ORDER BY repetition_count DESC
# LIMIT 1;

# %%
# Out:
#    sqlite:///ChicagoPublicSchool.db
#    sqlite:///Criminal.db
#  * sqlite:///FinalDB.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#    sqlite:///realworld_data.db
# (sqlite3.OperationalError) no such column: Crime_data
# [SQL: select COMMUNITY_AREA_NUMBER, count(COMMUNITY_AREA_NUMBER) as repetition_count from Crime_data group by Crime_data order by repetition_count desc limit 1;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# Problem 1
# Find the total number of crimes recorded in the CRIME table.

# %%
# %sql select count(*) CASE_NUMBER from Crime_data;
# Out:
#  * sqlite:///FinalDB.db
#    sqlite:///realworld_data.db
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community area names and numbers with per capita income less than 11000.

# %%
import csv,sqlite3
conn = sqlite3.connect('communityDB.db')
cor = conn.cursor()

# %%
# %reload_ext sql

# %%
# %sql sqlite:///communityDB.db
# Out:
# 'Connected: @communityDB.db'

# %%
import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("new_communitydata",conn, if_exists='replace',index=False,method='multi')
df.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 0                                          18.2
# ...

# %% [markdown]
# ### Problem 2
#
# ##### List community area names and numbers with per capita income less than 11000.

# %%
# %sql select  COMMUNITY_AREA_NUMBER,COMMUNITY_AREA_NUMBER from new_communitydata where PER_CAPITA_INCOME < 11000
# Out:
#  * sqlite:///communityDB.db
# Done.
# [(26.0, 26.0), (30.0, 30.0), (37.0, 37.0), (54.0, 54.0)]

# %%
# %sql select  COMMUNITY_AREA_NUMBER,COMMUNITY_AREA_NUMBER from new_communitydata where PER_CAPITA_INCOME < 11000
# Out:
#  * sqlite:///communityDB.db
# Done.
# [(26.0, 26.0), (30.0, 30.0), (37.0, 37.0), (54.0, 54.0)]

# %%
# %sql SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME FROM new_communitydata WHERE PER_CAPITA_INCOME < 11000
# Out:
#  * sqlite:///communityDB.db
# Done.
# [(26.0, 'West Garfield Park'),
#  (30.0, 'South Lawndale'),
#  (37.0, 'Fuller Park'),
#  (54.0, 'Riverdale')]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
import csv,sqlite3
conn = sqlite3.connect("Criminal.db")
cur = conn.cursor()
# %reload_ext sql
# %sql sqlite:///Criminal.db

import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("Crime_data1",conn, if_exists="replace", index=False, method="multi")
df.head()
# Out:
#          ID CASE_NUMBER        DATE                     BLOCK IUCR  \
# 0   3512276    HK587712  2004-08-28        047XX S KEDZIE AVE  890
# 1   3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE  820
# 2   8002131    HT233595  2011-04-04        043XX S WABASH AVE  820
# 3   7903289    HT133522  2010-12-30      083XX S KINGSTON AVE  840
# 4  10402076    HZ138551  2016-02-02           033XX W 66TH ST  820
#
#   PRIMARY_TYPE                    DESCRIPTION          LOCATION_DESCRIPTION  \
# 0        THEFT                  FROM BUILDING            SMALL RETAIL STORE
# 1        THEFT                 $500 AND UNDER                         OTHER
# 2        THEFT                 $500 AND UNDER  NURSING HOME/RETIREMENT HOME
# 3        THEFT  FINANCIAL ID THEFT: OVER $300                     RESIDENCE
# 4        THEFT                 $500 AND UNDER                         ALLEY
#
#    ARREST  DOMESTIC  ...  DISTRICT  WARD  COMMUNITY_AREA_NUMBER  FBICODE  \
# ...

# %%
# %sql select * from Crime_data1 where PRIMARY_TYPE like '%kidnapping%';
# Out:
#    sqlite:///ChicagoPublicSchool.db
#  * sqlite:///Criminal.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#    sqlite:///realworld_data.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %%
# %sql SELECT * FROM Crime_data1 WHERE Primary_Type = 'KIDNAPPING' AND Description LIKE '%CHILD%'
# Out:
#    sqlite:///ChicagoPublicSchool.db
#  * sqlite:///Criminal.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#    sqlite:///realworld_data.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %% [markdown]
# # Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %sql select * from Crime_data1 where PRIMARY_TYPE like '%kidnapping%';
# Out:
#    sqlite:///ChicagoPublicSchool.db
#  * sqlite:///Criminal.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#    sqlite:///realworld_data.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %%
# When you list all case numbers for crimes involving a minor, how many rows of data are retrieved?

# %% [markdown]
# ### Problem 5
#
# ##### List the kind of crimes that were recorded at schools. (No repetitions)

# %%
import csv, sqlite3
conn = sqlite3.connect("SchoolDB.db")
cur = conn.cursor()
# %load_ext sql

# %sql sqlite:///SchoolDB.db

import pandas
df= pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("School_data",conn,if_exists="replace",index=False,method="multi")
df.head()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#          ID CASE_NUMBER        DATE                     BLOCK IUCR  \
# 0   3512276    HK587712  2004-08-28        047XX S KEDZIE AVE  890
# 1   3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE  820
# 2   8002131    HT233595  2011-04-04        043XX S WABASH AVE  820
# 3   7903289    HT133522  2010-12-30      083XX S KINGSTON AVE  840
# 4  10402076    HZ138551  2016-02-02           033XX W 66TH ST  820
#
#   PRIMARY_TYPE                    DESCRIPTION          LOCATION_DESCRIPTION  \
# 0        THEFT                  FROM BUILDING            SMALL RETAIL STORE
# 1        THEFT                 $500 AND UNDER                         OTHER
# 2        THEFT                 $500 AND UNDER  NURSING HOME/RETIREMENT HOME
# 3        THEFT  FINANCIAL ID THEFT: OVER $300                     RESIDENCE
# 4        THEFT                 $500 AND UNDER                         ALLEY
#
# ...

# %%
# %sql SELECT DISTINCT Primary_Type FROM School_data WHERE Location_Description LIKE '%SCHOOL%'
# Out:
#    sqlite:///Criminal.db
#  * sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# # ### Problem 5
#
# ##### List the kind of crimes that were recorded at schools. (No repetitions)

# %%
# %sql SELECT DISTINCT Primary_Type FROM School_data WHERE Location_Description LIKE '%SCHOOL%'
# Out:
#    sqlite:///Criminal.db
#  * sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %%
coln = df.columns

# %%
coln
# Out:
# Index(['School_ID', 'NAME_OF_SCHOOL', 'Elementary, Middle, or High School',
#        'Street_Address', 'City', 'State', 'ZIP_Code', 'Phone_Number', 'Link',
#        'Network_Manager', 'Collaborative_Name',
#        'Adequate_Yearly_Progress_Made_', 'Track_Schedule',
#        'CPS_Performance_Policy_Status', 'CPS_Performance_Policy_Level',
#        'HEALTHY_SCHOOL_CERTIFIED', 'Safety_Icon', 'SAFETY_SCORE',
#        'Family_Involvement_Icon', 'Family_Involvement_Score',
#        'Environment_Icon', 'Environment_Score', 'Instruction_Icon',
#        'Instruction_Score', 'Leaders_Icon', 'Leaders_Score', 'Teachers_Icon',
#        'Teachers_Score', 'Parent_Engagement_Icon', 'Parent_Engagement_Score',
#        'Parent_Environment_Icon', 'Parent_Environment_Score',
#        'AVERAGE_STUDENT_ATTENDANCE', 'Rate_of_Misconducts__per_100_students_',
#        'Average_Teacher_Attendance',
#        'Individualized_Education_Program_Compliance_Rate', 'Pk_2_Literacy__',
# ...

# %%
# Out:
#    sqlite:///Criminal.db
#    sqlite:///FinalDB.db
#  * sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#    sqlite:///realworld_data.db
# (sqlite3.OperationalError) no such table: Criminal
# [SQL: select distinct PRIMARY_TYPE from Criminal where Location in(select Location from SchoolDB);]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
import csv, sqlite3
conn = sqlite3.connect("realworld_data.db")
cur = conn.cursor()

# %load_ext sql
# %sql sqlite:///realworld_data.db

import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("new_communitydata",conn, if_exists='replace',index=False,method='multi')
df.head()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# ...

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %sql select * from new_communitydata order by PERCENT_HOUSEHOLDS_BELOW_POVERTY desc limit 5;
# Out:
#    sqlite:///Criminal.db
#    sqlite:///FinalDB.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#  * sqlite:///realworld_data.db
# Done.
# [(54.0, 'Riverdale', 5.8, 56.5, 34.6, 27.5, 51.5, 8201, 98.0),
#  (37.0, 'Fuller Park', 3.2, 51.2, 33.9, 26.6, 44.9, 10432, 97.0),
#  (68.0, 'Englewood', 3.8, 46.6, 28.0, 28.5, 42.5, 11888, 94.0),
#  (29.0, 'North Lawndale', 7.4, 43.1, 21.2, 27.6, 42.7, 12034, 87.0),
#  (27.0, 'East Garfield Park', 8.2, 42.4, 19.6, 21.3, 43.2, 12961, 83.0)]

# %%
# %sql select COMMUNITY_AREA_NUMBER from Crime_data group by COMMUNITY_AREA_NUMBER order by count(*) desc limit 1;
# Out:
#    sqlite:///Criminal.db
#    sqlite:///FinalDB.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#  * sqlite:///realworld_data.db
# (sqlite3.OperationalError) no such table: Crime_data
# [SQL: select COMMUNITY_AREA_NUMBER from Crime_data group by COMMUNITY_AREA_NUMBER order by count(*) desc limit 1;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# # Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %sql select * from new_communitydata where HARDSHIP_INDEX =(select max(HARDSHIP_INDEX) from new_communitydata)
# Out:
#    sqlite:///Criminal.db
#    sqlite:///FinalDB.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#  * sqlite:///realworld_data.db
# Done.
# [(54.0, 'Riverdale', 5.8, 56.5, 34.6, 27.5, 51.5, 8201, 98.0)]

# %% [markdown]
# # Which community area number has the most criminal incidents (most crime-prone)?

# %%
import csv, sqlite3
conn = sqlite3.connect("CriminalReal.db")
cur = conn.cursor()

# %load_ext sql
# %sql sqlite:///realworld_data.db

import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("CriminalData",conn, if_exists='replace',index=False,method='multi')
df.head()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# ...

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM new_communitydata WHERE COMMUNITY_AREA_NUMBER = ( SELECT COMMUNITY_AREA_NUMBER FROM (SELECT COMMUNITY_AREA_NUMBER, COUNT(*) AS num_crimes FROM CriminalData GROUP BY COMMUNITY_AREA_NUMBER ORDER BY num_crimes DESC LIMIT 1));
# Out:
#    sqlite:///ChicagoPublicSchool.db
#    sqlite:///Criminal.db
#    sqlite:///FinalDB.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#  * sqlite:///realworld_data.db
# (sqlite3.OperationalError) no such table: CriminalData
# [SQL: SELECT COMMUNITY_AREA_NAME FROM new_communitydata WHERE COMMUNITY_AREA_NUMBER = ( SELECT COMMUNITY_AREA_NUMBER FROM (SELECT COMMUNITY_AREA_NUMBER, COUNT(*) AS num_crimes FROM CriminalData GROUP BY COMMUNITY_AREA_NUMBER ORDER BY num_crimes DESC LIMIT 1));]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %sql select COMMUNITY_AREA_NAME from new_communitydata where COMMUNITY_AREA_NUMBER;
# Out:
#    sqlite:///Criminal.db
#    sqlite:///FinalDB.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
#  * sqlite:///realworld_data.db
# Done.
# [('Rogers Park',),
#  ('West Ridge',),
#  ('Uptown',),
#  ('Lincoln Square',),
#  ('North Center',),
#  ('Lake View',),
#  ('Lincoln Park',),
#  ('Near North Side',),
#  ('Edison Park',),
#  ('Norwood Park',),
#  ('Jefferson Park',),
#  ('Forest Glen',),
#  ('North Park',),
#  ('Albany Park',),
#  ('Portage Park',),
#  ('Irving Park',),
#  ('Dunning',),
#  ('Montclaire',),
#  ('Belmont Cragin',),
#  ('Hermosa',),
#  ('Avondale',),
#  ('Logan Square',),
#  ('Humboldt park',),
#  ('West Town',),
#  ('Austin',),
#  ('West Garfield Park',),
#  ('East Garfield Park',),
#  ('Near West Side',),
#  ('North Lawndale',),
#  ('South Lawndale',),
#  ('Lower West Side',),
#  ('Loop',),
#  ('Near South Side',),
#  ('Armour Square',),
#  ('Douglas',),
#  ('Oakland',),
#  ('Fuller Park',),
#  ('Grand Boulevard',),
#  ('Kenwood',),
# ...

# %% [markdown]
# ### Problem 6
#
# ##### List the type of schools along with the average safety score for each type.

# %%
import csv, sqlite3
conn = sqlite3.connect("ChicagoPublicSchool.db")
cur = conn.cursor()

# %load_ext sql
# %sql sqlite:///ChicagoPublicSchool.db

import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("ChicagoSchool",conn, if_exists='replace',index=False,method='multi')
df.head()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#    School_ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School         Street_Address     City State  \
# 0                                 ES        615 W Kemper Pl  Chicago    IL
# 1                                 ES  7511 S South Shore Dr  Chicago    IL
# 2                                 ES     8010 S Kostner Ave  Chicago    IL
# 3                                 ES     4619 S Wolcott Ave  Chicago    IL
# 4                                 HS        3630 S Wells St  Chicago    IL
#
#    ZIP_Code    Phone_Number  \
# ...

# %%
# List the type of schools along with the average safety score for each type.
# %sql SELECT "Elementary, Middle, or High School" AS School_Type, AVG(Safety_Score) AS Average_Safety_Score FROM ChicagoSchool GROUP BY "Elementary, Middle, or High School";
# Out:
#  * sqlite:///ChicagoPublicSchool.db
#    sqlite:///Criminal.db
#    sqlite:///SchoolDB.db
#    sqlite:///communityDB.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %%
SELECT COMMUNITY_AREA_NAME 
FROM CENSUS_DATA 
WHERE HARDSHIP_INDEX = (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA);
